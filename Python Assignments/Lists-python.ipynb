# %%
x = True
y = False

print(x and y)
print(x or y)
print(not x)
print(not y)  

x = 5
print(x > 4 and x < 11)
print(x > 3 or x < 4)
print(not(x > 3 and x < 10))

x = 100
print(x > 40 and x < 90)
print(x > 30 or x < 400)
print(not(x > 3 and x < 10))

x = 100
print(x > 40 and x < 90)
print(x > 30 or x < 400)
print(not(x > 3 and x < 10))

#Answer to question 1: A list is a series of items

schoollist={"pencils","lined-paper","notebook","pen","Backpack"}
print(type(schoollist))

list1={"apple","banana","plum"}
list2={"2","4","6","8"}
list3={False,True,False}
print(len(list2))
print(len(list1))
print(len(list3))

thislist = ["orange", "apple", "banana", "cherry"]  
print(len(thislist))
print(thislist[1])
print(thislist[3])
print(thislist[0])

thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[1])
print(thislist[2])
print(thislist[3])
print(thislist[4])
print(thislist[5])
print(thislist[6])
# Out:
# False
# True
# False
# True
# True
# True
# False
# False
# True
# True
# False
# True
# True
# <class 'set'>
# 4
# 3
# 2
# 4
# apple
# cherry
# orange
# banana
# cherry
# orange
# kiwi
# melon
# mango

# %%
#2nd exersize
"""
1. thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
1.1 Print fourth, and fifth item from the list
1.3 print items from the beginning to, but NOT including, "melon"
1.3 print item from "banana" to the end

2. thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
2.1 Change/replace  the value of  "banana" to "orange" in the list.
2.2 Change the values "cherry" and   "orange" with the values "blackcurrant" and "watermelon"
2.3 Change the third and fourth value by replacing it with "mango"

3. thislist = ["apple", "banana", "cherry"]
3.1 use function to insert "watermelon" as the third item
3.2 use function to insert "watermelon" as the Last item
3.3 use function to insert "watermelon" as the first item

4. thislist = ["apple", "banana", "cherry"]
4.1 use function to append "watermelon" to list.

5. What is the difference between insert and append function? show with example?
"""




thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
#Question 1.1
print(thislist[3:5])

#Question 1.2
thislist.remove("melon")
print(thislist)
#Question 1.3
print(thislist[1:])

#Question 2 .1
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1]="orange"
print(thislist)

#Question 2.2
thislist[2:4]=["blackcurrent","watermelon"]
print(thislist)

#Question 2.3
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[2:4]=["mango"]
print(thislist)

#Question 3.1
thislist = ["apple", "banana", "cherry"]
thislist.insert(2,"watermelon")
print(thislist)

#Question 3.2
thislist = ["apple", "banana", "cherry"]
thislist.append("watermelon")
print(thislist)

#Question 3.3
thislist = ["apple", "banana", "cherry"]
thislist.insert(0,"watermelon")
print(thislist)

#Question 4.1
thislist = ["apple", "banana", "cherry"]
thislist.append("watermelon")
print(thislist)

#The above code has examples of append and insert code. The append will insert the item in the last place, and the insert function will be placed depending on the specified index.
# Out:
# ['orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'mango']
# ['banana', 'cherry', 'orange', 'kiwi', 'mango']
# ['apple', 'orange', 'cherry', 'orange', 'kiwi', 'mango']
# ['apple', 'orange', 'blackcurrent', 'watermelon', 'kiwi', 'mango']
# ['apple', 'banana', 'mango', 'kiwi', 'mango']
# ['apple', 'banana', 'watermelon', 'cherry']
# ['apple', 'banana', 'cherry', 'watermelon']
# ['watermelon', 'apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'watermelon']
