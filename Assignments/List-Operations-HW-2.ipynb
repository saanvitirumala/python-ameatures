# %%
"""
1. thislist = ["apple", "banana", "cherry", "orange", "melon", "mango"]
   - Add item "grapes" at 3rd position
   - Add item "kiwi" at end of the list
"""
thislist = ["apple", "banana", "cherry", "orange", "melon", "mango"]
thislist.insert(3,'grapes')
thislist.append('kiwi')
print(thislist)


"""
2  thislist = ["apple", "banana", "cherry"]
  tropical = ["mango", "pineapple", "papaya"]
   - use function to append elements from tropical list to the current thislist
"""
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)

"""
3. thislist = ["apple", "banana", "cherry"]
   - use function to remove item "banana" from the list.
"""
thislist = ["apple", "banana", "cherry"]
thislist.remove('banana')
print(thislist)

"""
4. thislist = ["apple", "banana", "cherry", "orange", "melon", "mango"]
   - use function to remove third item from  the list
   - use function to remove last item from the list
"""
thislist = ["apple", "banana", "cherry", "orange", "melon", "mango"]
thislist.remove('cherry')
print(thislist)
thislist.remove('mango')
print(thislist)

"""
thislist = ["apple", "banana", "cherry"]
   - use a function to delete the entire list
"""
thislist = ["apple", "banana", "cherry"]
del thislist
#print(thislist)

"""
6. thislist = ["apple", "banana", "cherry"]
   - use function to clear list
"""
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)

"""
7. thislist = ["apple", "banana", "cherry", "orange", "melon", "mango"]
   - use function to loop through list items
"""
thislist = ["apple", "banana", "cherry", "orange", "melon", "mango"]
for x in thislist:
  print(x)

"""
8. Write a program using a for loop to print any number table; example 10 * 1 = 10, 10 * 2 = 20 ............. 10 * 10 = 100.
"""

x = 10
times=10
print(x,'times table')
for y in range(1,times+1):
    print(x,'x',y,'=',x*y)

"""
9. Write a program using for loop to print factorial of any given number ; eg 5 factorial = 5 * 4 * 3 * 2 * 1 = 120
"""

x = 5
factorial=1
for y in range(1,x+1):
 factorial = factorial*y

print('Factorial of ',x,'=',factorial)
# Out:
# ['apple', 'banana', 'cherry', 'grapes', 'orange', 'melon', 'mango', 'kiwi']
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']
# ['apple', 'cherry']
# ['apple', 'banana', 'orange', 'melon', 'mango']
# ['apple', 'banana', 'orange', 'melon']
# []
# apple
# banana
# cherry
# orange
# melon
# mango
# 10 times table
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
# Factorial of  5 = 120
